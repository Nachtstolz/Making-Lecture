# %% [markdown]
# ### 데이터 로드

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(columns=['키', '몸무게'])
df.loc[0] = [185,60]
df.loc[1] = [180,60]
df.loc[2] = [185,70]
df.loc[3] = [165,63]
df.loc[4] = [155,68]
df.loc[5] = [170,75]
df.loc[6] = [175,80]
df

# %%
df = pd.read_csv(r'C:\Users\CSH\Desktop\새 폴더\작전여자고등학교 - 코딩교육\data1.csv',
                encoding='utf-8', index_col=0)

# %%
df
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 3   166  66.3  40.0   2
# 4   155  57.1  35.0   1
# 5   159  49.2   5.0   1
# 6   158  45.4   NaN   1
# 7   158  53.2   NaN   2
# 8   160  55.1  20.0   2
# 9   162  58.2  25.0   1
# 10  164  51.2  25.0   3
# 11  163  52.7  15.0   3
# 12  157  47.2  30.0   1
# 13  170  59.8  30.0   2
# 14  159  61.3  40.0   2
# 15  160  65.9  60.0   3
# 16  161  59.3  50.0   1
# 17  172  63.4  15.0   2
# 18  166  57.1  20.0   1
# 19  157  55.2  20.0   3
# 20  154  49.2   5.0   1
# 21  166  57.3  10.0   2
# 22  163  50.4  20.0   2
# 23  162  53.8  30.0   2
# 24  160  47.4  20.0   1
# 25  165  63.7  10.0   3
# 26  159  55.3  30.0   1
# 27  162  61.3  15.0   1
# 28  161  57.3  10.0   2
# 29  164   NaN  20.0   3

# %% [markdown]
# ### 데이터 전처리

# %%
df.head()
# Out:
#      키   몸무게    거리  과목
# 0  158  59.4  15.0   1
# 1  160  55.2  30.0   2
# 2  167  64.0  20.0   3
# 3  166  66.3  40.0   2
# 4  155  57.1  35.0   1

# %%
df.tail()
# Out:
#       키   몸무게    거리  과목
# 25  165  63.7  10.0   3
# 26  159  55.3  30.0   1
# 27  162  61.3  15.0   1
# 28  161  57.3  10.0   2
# 29  164   NaN  20.0   3

# %%
df.isnull().sum()
# Out:
# 키      0
# 몸무게    1
# 거리     2
# 과목     0
# dtype: int64

# %%
# 몸무게를 안쓴 친구는 버리고
# 거리를 안쓴 친구들은 0분 거리이기때문에 그랬다.
# 하지만 합의 하에 5분으로 변경하기로 결정.
df[df['거리'].isnull()]
# Out:
#      키   몸무게  거리  과목
# 6  158  45.4 NaN   1
# 7  158  53.2 NaN   2

# %%
# 값 변경
df['거리'][6] = 5
df['거리'][6]
# Out:
# C:\Users\CSH\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 5.0

# %%
df['거리'][7] = 5
df['거리'][7]
# Out:
# C:\Users\CSH\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 5.0

# %%
# 몸무게 값 버리기
df[df['몸무게'].isnull()]
# Out:
#       키  몸무게    거리  과목
# 29  164  NaN  20.0   3

# %%
# 방법 1
#df = 
df.dropna()
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 3   166  66.3  40.0   2
# 4   155  57.1  35.0   1
# 5   159  49.2   5.0   1
# 6   158  45.4   5.0   1
# 7   158  53.2   5.0   2
# 8   160  55.1  20.0   2
# 9   162  58.2  25.0   1
# 10  164  51.2  25.0   3
# 11  163  52.7  15.0   3
# 12  157  47.2  30.0   1
# 13  170  59.8  30.0   2
# 14  159  61.3  40.0   2
# 15  160  65.9  60.0   3
# 16  161  59.3  50.0   1
# 17  172  63.4  15.0   2
# 18  166  57.1  20.0   1
# 19  157  55.2  20.0   3
# 20  154  49.2   5.0   1
# 21  166  57.3  10.0   2
# 22  163  50.4  20.0   2
# 23  162  53.8  30.0   2
# 24  160  47.4  20.0   1
# 25  165  63.7  10.0   3
# 26  159  55.3  30.0   1
# 27  162  61.3  15.0   1
# 28  161  57.3  10.0   2

# %%
# 방법 2
#df =
df.drop(index=29, inplace=True)

# %%
df
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 3   166  66.3  40.0   2
# 4   155  57.1  35.0   1
# 5   159  49.2   5.0   1
# 6   158  45.4   5.0   1
# 7   158  53.2   5.0   2
# 8   160  55.1  20.0   2
# 9   162  58.2  25.0   1
# 10  164  51.2  25.0   3
# 11  163  52.7  15.0   3
# 12  157  47.2  30.0   1
# 13  170  59.8  30.0   2
# 14  159  61.3  40.0   2
# 15  160  65.9  60.0   3
# 16  161  59.3  50.0   1
# 17  172  63.4  15.0   2
# 18  166  57.1  20.0   1
# 19  157  55.2  20.0   3
# 20  154  49.2   5.0   1
# 21  166  57.3  10.0   2
# 22  163  50.4  20.0   2
# 23  162  53.8  30.0   2
# 24  160  47.4  20.0   1
# 25  165  63.7  10.0   3
# 26  159  55.3  30.0   1
# 27  162  61.3  15.0   1
# 28  161  57.3  10.0   2

# %%
df.drop(index=3, inplace=True)

# %%
df
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 4   155  57.1  35.0   1
# 5   159  49.2   5.0   1
# 6   158  45.4   5.0   1
# 7   158  53.2   5.0   2
# 8   160  55.1  20.0   2
# 9   162  58.2  25.0   1
# 10  164  51.2  25.0   3
# 11  163  52.7  15.0   3
# 12  157  47.2  30.0   1
# 13  170  59.8  30.0   2
# 14  159  61.3  40.0   2
# 15  160  65.9  60.0   3
# 16  161  59.3  50.0   1
# 17  172  63.4  15.0   2
# 18  166  57.1  20.0   1
# 19  157  55.2  20.0   3
# 20  154  49.2   5.0   1
# 21  166  57.3  10.0   2
# 22  163  50.4  20.0   2
# 23  162  53.8  30.0   2
# 24  160  47.4  20.0   1
# 25  165  63.7  10.0   3
# 26  159  55.3  30.0   1
# 27  162  61.3  15.0   1
# 28  161  57.3  10.0   2

# %%
df[df['몸무게'].isnull()]
# Out:
# Empty DataFrame
# Columns: [키, 몸무게, 거리, 과목]
# Index: []

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 3   155  57.1  35.0   1
# 4   159  49.2   5.0   1
# 5   158  45.4   5.0   1
# 6   158  53.2   5.0   2
# 7   160  55.1  20.0   2
# 8   162  58.2  25.0   1
# 9   164  51.2  25.0   3
# 10  163  52.7  15.0   3
# 11  157  47.2  30.0   1
# 12  170  59.8  30.0   2
# 13  159  61.3  40.0   2
# 14  160  65.9  60.0   3
# 15  161  59.3  50.0   1
# 16  172  63.4  15.0   2
# 17  166  57.1  20.0   1
# 18  157  55.2  20.0   3
# 19  154  49.2   5.0   1
# 20  166  57.3  10.0   2
# 21  163  50.4  20.0   2
# 22  162  53.8  30.0   2
# 23  160  47.4  20.0   1
# 24  165  63.7  10.0   3
# 25  159  55.3  30.0   1
# 26  162  61.3  15.0   1
# 27  161  57.3  10.0   2

# %% [markdown]
# ### EDA

# %%
#df[df['키']>160]
len(df[df['키']>160])
# Out:
# 14

# %%
# 과목1을 좋아하는 친구는 얼마나 되는지 확인해보아요.
len(df[df['과목']==1])
len(df[df['키']>=180])
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       키   몸무게    거리  과목
# 0   158  59.4  15.0   1
# 1   160  55.2  30.0   2
# 2   167  64.0  20.0   3
# 3   155  57.1  35.0   1
# 4   159  49.2   5.0   1
# 5   158  45.4   5.0   1
# 6   158  53.2   5.0   2
# 7   160  55.1  20.0   2
# 8   162  58.2  25.0   1
# 9   164  51.2  25.0   3
# 10  163  52.7  15.0   3
# 11  157  47.2  30.0   1
# 12  170  59.8  30.0   2
# 13  159  61.3  40.0   2
# 14  160  65.9  60.0   3
# 15  161  59.3  50.0   1
# 16  172  63.4  15.0   2
# 17  166  57.1  20.0   1
# 18  157  55.2  20.0   3
# 19  154  49.2   5.0   1
# 20  166  57.3  10.0   2
# 21  163  50.4  20.0   2
# 22  162  53.8  30.0   2
# 23  160  47.4  20.0   1
# 24  165  63.7  10.0   3
# 25  159  55.3  30.0   1
# 26  162  61.3  15.0   1
# 27  161  57.3  10.0   2

# %%
plt.scatter(df['키'],df['몸무게'], s=70)
plt.xlabel('키', fontsize=12)
plt.ylabel('몸무게', fontsize=12)
plt.show()
